# %%
from __future__ import print_function, division
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from bokeh.plotting import figure, show, output_notebook, output_file
from bokeh.models import ColumnDataSource, Range1d

output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6d79e5dc-dd2d-4276-b7db-fcc9e85d2730">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# DyCE Model consists of data curated from 43 papers, most of which are in fact review articles.

# %%
pmids = pd.read_csv('/Users/Gully/Documents/Projects/2_active/bigMech/work/2016-08-22-dyceModel/dyce_model_pmids.tsv',
                 sep='\t')

pmids['count'] = pd.Series(1, index=pmids.index)
print(pmids)
# Out:
#         pmid review  n_references  count
# 0   10228013      n            54      1
# 1   10602461      y           321      1
# 2   10708950      y            85      1
# 3   10878024      n            62      1
# 4   11170294      y            94      1
# 5   11312109      y            69      1
# 6   11790550      y            63      1
# 7   11920677      y           226      1
# 8   12007403      n            54      1
# 9   12074877      y            24      1
# 10  12401408      y            74      1
# 11  12835716      y           569      1
# 12   1386364      n            43      1
# 13  14707283      y           111      1
# 14  14762439      n            39      1
# 15  15255771      y           172      1
# 16  15489911      y           235      1
# 17  15527798      n            20      1
# 18  15735721      n            59      1
# 19  16377102      y           135      1
# 20  16839880      n            43      1
# 21  16887934      y            52      1
# ...

# %%
pivot_ref_count = pd.pivot_table(pmids, values='n_references', 
                         index=['pmid'], columns=['review'], 
                         margins=True, aggfunc=np.sum)
pivot_ref_count
# Out:
# review        n       y     All
# pmid
# 1386364    43.0     NaN    43.0
# 7514165    22.0     NaN    22.0
# 7514175    35.0     NaN    35.0
# 8046239    80.0     NaN    80.0
# 8702885    71.0     NaN    71.0
# 9597127     NaN   132.0   132.0
# 10228013   54.0     NaN    54.0
# 10602461    NaN   321.0   321.0
# 10708950    NaN    85.0    85.0
# 10878024   62.0     NaN    62.0
# 11170294    NaN    94.0    94.0
# 11312109    NaN    69.0    69.0
# 11790550    NaN    63.0    63.0
# 11920677    NaN   226.0   226.0
# 12007403   54.0     NaN    54.0
# 12074877    NaN    24.0    24.0
# 12401408    NaN    74.0    74.0
# 12835716    NaN   569.0   569.0
# 14707283    NaN   111.0   111.0
# 14762439   39.0     NaN    39.0
# 15255771    NaN   172.0   172.0
# 15489911    NaN   235.0   235.0
# 15527798   20.0     NaN    20.0
# 15735721   59.0     NaN    59.0
# 16377102    NaN   135.0   135.0
# 16839880   43.0     NaN    43.0
# 16887934    NaN    52.0    52.0
# 17304234    NaN    90.0    90.0
# ...

# %%
pivot_count = pd.pivot_table(pmids, values='count',  columns=['review'], index=['pmid'],
                         margins=True, aggfunc=np.sum)
# Out:
# review       n     y   All
# pmid
# 1386364    1.0   NaN   1.0
# 7514165    1.0   NaN   1.0
# 7514175    1.0   NaN   1.0
# 8046239    1.0   NaN   1.0
# 8702885    1.0   NaN   1.0
# 9597127    NaN   1.0   1.0
# 10228013   1.0   NaN   1.0
# 10602461   NaN   1.0   1.0
# 10708950   NaN   1.0   1.0
# 10878024   1.0   NaN   1.0
# 11170294   NaN   1.0   1.0
# 11312109   NaN   1.0   1.0
# 11790550   NaN   1.0   1.0
# 11920677   NaN   1.0   1.0
# 12007403   1.0   NaN   1.0
# 12074877   NaN   1.0   1.0
# 12401408   NaN   1.0   1.0
# 12835716   NaN   1.0   1.0
# 14707283   NaN   1.0   1.0
# 14762439   1.0   NaN   1.0
# 15255771   NaN   1.0   1.0
# 15489911   NaN   1.0   1.0
# 15527798   1.0   NaN   1.0
# 15735721   1.0   NaN   1.0
# 16377102   NaN   1.0   1.0
# 16839880   1.0   NaN   1.0
# 16887934   NaN   1.0   1.0
# 17304234   NaN   1.0   1.0
# 17446563   1.0   NaN   1.0
# 17502367   NaN   1.0   1.0
# 17717517   NaN   1.0   1.0
# 18485876   1.0   NaN   1.0
# 19292888   NaN   1.0   1.0
# ...
